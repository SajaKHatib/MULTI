# %% [markdown]
# <a href="https://colab.research.google.com/github/SajaKHatib/MULTI/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Libraries

# %%
from google.colab import files
from IPython.display import Image
from scipy.fftpack import dct, idct
import matplotlib.image as img
import matplotlib.pyplot as plt
import time
import imageio
import numpy as np
import numpy as r_
import numpy as img_3d
from google.colab.patches import cv2_imshow
import cv2

# %% [markdown]
# defining DCT and IDCT

# %%
def dct2(a):
    return dct(dct(a.T, norm='ortho').T, norm='ortho')

def idct2(a):
    return idct(idct(a.T, norm='ortho').T, norm='ortho')

# %% [markdown]
# Display image and converted it to matrix

# %%
img = imageio.imread("es.png")
plt.figure(figsize=(6,6))
plt.imshow(img,cmap='gray')
print(img)
# Out:
# [[[40 40 40]
#   [41 41 41]
#   [44 44 44]
#   ...
#   [10 10 10]
#   [10 10 10]
#   [10 10 10]]
#
#  [[40 40 40]
#   [41 41 41]
#   [43 43 43]
#   ...
#   [10 10 10]
#   [10 10 10]
#   [10 10 10]]
#
#  [[39 39 39]
#   [41 41 41]
#   [43 43 43]
#   ...
#   [10 10 10]
#   [10 10 10]
#   [10 10 10]]
#
#  ...
#
#  [[25 25 25]
#   [25 25 25]
#   [26 26 26]
#   ...
#   [19 19 19]
#   [19 19 19]
#   [19 19 19]]
#
#  [[27 27 27]
#   [27 27 27]
#   [27 27 27]
#   ...
#   [20 20 20]
#   [20 20 20]
#   [20 20 20]]
#
#  [[28 28 28]
#   [28 28 28]
#   [28 28 28]
#   ...
#   [21 21 21]
#   [21 21 21]
#   [21 21 21]]]

# %% [markdown]
# Applay DCT on matrix

# %%
#dct1=dctn(image,1)
dct1 = dct2(image) #call function
#idct1 = idct(image)
cv2_imshow(dct1)
print(dct1)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F28C2D63850>
# [[[ 7.05867319e+02  0.00000000e+00  0.00000000e+00]
#   [ 7.06763577e+02  0.00000000e+00  0.00000000e+00]
#   [ 7.04586950e+02  0.00000000e+00  0.00000000e+00]
#   ...
#   [ 4.13687159e+02  0.00000000e+00  0.00000000e+00]
#   [ 4.06901204e+02  0.00000000e+00  0.00000000e+00]
#   [ 3.98578807e+02  0.00000000e+00  0.00000000e+00]]
#
#  [[ 9.82718922e+01  0.00000000e+00  0.00000000e+00]
#   [ 1.03613224e+02  0.00000000e+00  0.00000000e+00]
#   [ 1.13401468e+02  0.00000000e+00  0.00000000e+00]
#   ...
#   [-3.99185309e+01  0.00000000e+00  0.00000000e+00]
#   [-3.28241410e+01  0.00000000e+00  0.00000000e+00]
#   [-2.52525509e+01  0.00000000e+00  0.00000000e+00]]
#
#  [[ 2.23266960e+01  0.00000000e+00  0.00000000e+00]
#   [ 2.94414196e+01  0.00000000e+00  0.00000000e+00]
#   [ 4.40161622e+01  0.00000000e+00  0.00000000e+00]
#   ...
#   [-3.19608013e+01  0.00000000e+00  0.00000000e+00]
# ...

# %% [markdown]
# Applay IDCT

# %%
idct1 = idct2(dct1)
cv2_imshow(idct1)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F28C2D6E950>
